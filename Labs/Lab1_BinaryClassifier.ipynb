# %% [markdown]
# # Binary classifier with a sigmoid neuron

# %% [markdown]
# Let's implement a simple sigmoid neuron to classify 2D points. First, we only need two libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We will create two random distributions of points. One of the distribution is shifted, so there is a clear linear separation between both sets. We build a dataset with the points.

# %%
#Let's create a dataset of 2D points. The distribution is only shifted 3.5 units
X1 = np.random.randn(1000, 2)
X2 = np.random.randn(1000, 2) + 3.5

#The first 750 points of each distribution go in the training set
X_train = np.concatenate([X1[:750,:], X2[:750,:]], axis=0)

#The last 250 points of each distribution go in the test set
X_test = np.concatenate([X1[750:,:], X2[750:,:]], axis=0)

#We also create the labels
Y1 = np.zeros((1000, 1)) #The points in the first distribution have class 0
Y2 = np.ones((1000, 1)) # The points in the second distribution have class 1

#The first 750 labels of each distribution go in the training set
Y_train = np.concatenate([Y1[:750], Y2[:750]], axis=0)

#The last 250 labels of each distribution go in the test set
Y_test = np.concatenate([Y1[750:], Y2[750:]], axis=0)

#Plot the training set
plt.scatter(X_train[:750,0], X_train[:750,1], color='b')
plt.scatter(X_train[750:,0], X_train[750:,1], color='r')
plt.show()

# %% [markdown]
# We develop the neural network and the gradient descent algorithm for learning

# %%
#Definition of sigmoid function
def sigmoid(x):
    return 1/(1 + np.exp(-x))


#Let's implement the gradient descent algorithm

#Initialize random parameters
w1 = 2*np.random.rand(1) - 1
w2 = 2*np.random.rand(1) - 1
b = 2*np.random.rand(1) - 1

#Initialize hiper-parameters
learning_rate = 0.001
num_epochs = 100

#Log lists
log_train = []
log_test = []

#Iterate over the epochs
for i in range(num_epochs):
    cost = 0
    
    #Foe each epoch, iterate over the training samples
    for j in range(X_train.shape[0]):
        #Compute the linear function
        z = w1 * X_train[j,0] + w2 * X_train[j, 1] + b
        #Compute the activation function (sigmoid)
        y1 = sigmoid(z)
        
        #Compute error and cost for this sample
        error = y1 - Y_train[j]
        cost = cost + error**2
        
        #Compute the derivatives for each parameter        
        dw1 = error*y1*(1-y1)*X_train[j,0]
        dw2 = error*y1*(1-y1)*X_train[j,1]
        db = error*y1*(1-y1)
        
        #Perform the update rules        
        w1 = w1 - learning_rate*dw1
        w2 = w2 - learning_rate*dw2
        b = b - learning_rate*db
    
    #At the end of the epoch, we compute the total cost of the epoch
    cost = cost/(2*X_train.shape[0])
    log_train.append(cost)
    
    #We verify how good is the model so far, by computing the accuracy in the test set
    test_output = []
    cost = 0
    
    #Iterate over the test samples
    for j in range(X_test.shape[0]):
        #Compute the output of the neuron
        y1 = sigmoid(w1 * X_test[j,0] + w2 * X_test[j, 1] + b)
        cost = cost + (y1 - Y_test[j])**2
        test_output.append(y1)
    
    #Average the cost over the test set
    cost = cost / (2*X_test.shape[0])
    log_test.append(cost)
    
    test_output = np.asarray(test_output)
    test_output = (test_output >= 0.5)
    
    #Compare the output of the network with the correct labels
    correct = (test_output == Y_test).sum()
    
    print('Epoch {}/{}: loss = {}: Test accuracy={}'.format(i, num_epochs, cost, (100*correct)/test_output.shape[0]))
# Out:
# Epoch 0/100: loss = [0.28158305]: Test accuracy=40.4
# Epoch 1/100: loss = [0.27867145]: Test accuracy=41.2
# Epoch 2/100: loss = [0.27578258]: Test accuracy=41.8
# Epoch 3/100: loss = [0.27289217]: Test accuracy=43.4
# Epoch 4/100: loss = [0.26995562]: Test accuracy=45.4
# Epoch 5/100: loss = [0.26689243]: Test accuracy=45.8
# Epoch 6/100: loss = [0.26355214]: Test accuracy=47.8
# Epoch 7/100: loss = [0.25962858]: Test accuracy=48.8
# Epoch 8/100: loss = [0.25439919]: Test accuracy=49.4
# Epoch 9/100: loss = [0.24567007]: Test accuracy=50.0
# Epoch 10/100: loss = [0.22273076]: Test accuracy=50.0
# Epoch 11/100: loss = [0.10253571]: Test accuracy=53.4
# Epoch 12/100: loss = [0.03618656]: Test accuracy=99.2
# Epoch 13/100: loss = [0.02853447]: Test accuracy=98.6
# Epoch 14/100: loss = [0.02616663]: Test accuracy=98.0
# Epoch 15/100: loss = [0.02492599]: Test accuracy=97.6
# Epoch 16/100: loss = [0.02406575]: Test accuracy=97.6
# Epoch 17/100: loss = [0.02337363]: Test accuracy=97.6
# Epoch 18/100: loss = [0.02277229]: Test accuracy=97.6
# Epoch 19/100: loss = [0.02222862]: Test accuracy=97.8
# Epoch 20/100: loss = [0.02172655]: Test accuracy=97.8
# Epoch 21/100: loss = [0.02125742]: Test accuracy=98.0
# Epoch 22/100: loss = [0.020816]: Test accuracy=98.2
# Epoch 23/100: loss = [0.02039885]: Test accuracy=98.2
# Epoch 24/100: loss = [0.02000346]: Test accuracy=98.4
# Epoch 25/100: loss = [0.01962788]: Test accuracy=98.4
# Epoch 26/100: loss = [0.0192705]: Test accuracy=98.4
# Epoch 27/100: loss = [0.01892994]: Test accuracy=98.4
# Epoch 28/100: loss = [0.018605]: Test accuracy=98.4
# Epoch 29/100: loss = [0.01829459]: Test accuracy=98.4
# Epoch 30/100: loss = [0.01799774]: Test accuracy=98.6
# Epoch 31/100: loss = [0.01771355]: Test accuracy=98.6
# Epoch 32/100: loss = [0.01744122]: Test accuracy=98.6
# Epoch 33/100: loss = [0.01718]: Test accuracy=98.6
# Epoch 34/100: loss = [0.01692921]: Test accuracy=98.6
# Epoch 35/100: loss = [0.01668822]: Test accuracy=98.6
# Epoch 36/100: loss = [0.01645645]: Test accuracy=98.6
# Epoch 37/100: loss = [0.01623338]: Test accuracy=98.6
# Epoch 38/100: loss = [0.01601849]: Test accuracy=98.6
# Epoch 39/100: loss = [0.01581134]: Test accuracy=98.8
# Epoch 40/100: loss = [0.0156115]: Test accuracy=98.8
# Epoch 41/100: loss = [0.01541858]: Test accuracy=98.8
# Epoch 42/100: loss = [0.01523221]: Test accuracy=98.8
# Epoch 43/100: loss = [0.01505205]: Test accuracy=99.0
# Epoch 44/100: loss = [0.01487779]: Test accuracy=99.0
# Epoch 45/100: loss = [0.01470912]: Test accuracy=99.0
# Epoch 46/100: loss = [0.01454578]: Test accuracy=99.0
# Epoch 47/100: loss = [0.0143875]: Test accuracy=99.0
# Epoch 48/100: loss = [0.01423404]: Test accuracy=99.0
# Epoch 49/100: loss = [0.01408518]: Test accuracy=99.0
# Epoch 50/100: loss = [0.0139407]: Test accuracy=99.0
# Epoch 51/100: loss = [0.01380041]: Test accuracy=99.0
# Epoch 52/100: loss = [0.01366412]: Test accuracy=99.0
# Epoch 53/100: loss = [0.01353165]: Test accuracy=99.0
# Epoch 54/100: loss = [0.01340284]: Test accuracy=99.0
# Epoch 55/100: loss = [0.01327753]: Test accuracy=99.0
# Epoch 56/100: loss = [0.01315558]: Test accuracy=99.0
# Epoch 57/100: loss = [0.01303684]: Test accuracy=99.2
# Epoch 58/100: loss = [0.01292118]: Test accuracy=99.2
# Epoch 59/100: loss = [0.01280849]: Test accuracy=99.2
# Epoch 60/100: loss = [0.01269864]: Test accuracy=99.2
# Epoch 61/100: loss = [0.01259152]: Test accuracy=99.2
# Epoch 62/100: loss = [0.01248702]: Test accuracy=99.2
# Epoch 63/100: loss = [0.01238506]: Test accuracy=99.2
# Epoch 64/100: loss = [0.01228552]: Test accuracy=99.2
# Epoch 65/100: loss = [0.01218833]: Test accuracy=99.2
# Epoch 66/100: loss = [0.01209339]: Test accuracy=99.2
# Epoch 67/100: loss = [0.01200063]: Test accuracy=99.2
# Epoch 68/100: loss = [0.01190997]: Test accuracy=99.2
# Epoch 69/100: loss = [0.01182133]: Test accuracy=99.2
# Epoch 70/100: loss = [0.01173464]: Test accuracy=99.2
# Epoch 71/100: loss = [0.01164984]: Test accuracy=99.2
# Epoch 72/100: loss = [0.01156686]: Test accuracy=99.2
# Epoch 73/100: loss = [0.01148564]: Test accuracy=99.2
# Epoch 74/100: loss = [0.01140613]: Test accuracy=99.2
# Epoch 75/100: loss = [0.01132826]: Test accuracy=99.2
# Epoch 76/100: loss = [0.01125199]: Test accuracy=99.2
# Epoch 77/100: loss = [0.01117726]: Test accuracy=99.2
# Epoch 78/100: loss = [0.01110403]: Test accuracy=99.2
# Epoch 79/100: loss = [0.01103225]: Test accuracy=99.2
# Epoch 80/100: loss = [0.01096187]: Test accuracy=99.2
# Epoch 81/100: loss = [0.01089284]: Test accuracy=99.0
# Epoch 82/100: loss = [0.01082514]: Test accuracy=99.0
# Epoch 83/100: loss = [0.01075872]: Test accuracy=99.0
# Epoch 84/100: loss = [0.01069354]: Test accuracy=99.0
# Epoch 85/100: loss = [0.01062957]: Test accuracy=99.0
# Epoch 86/100: loss = [0.01056677]: Test accuracy=99.0
# Epoch 87/100: loss = [0.0105051]: Test accuracy=99.0
# Epoch 88/100: loss = [0.01044454]: Test accuracy=99.2
# Epoch 89/100: loss = [0.01038506]: Test accuracy=99.2
# Epoch 90/100: loss = [0.01032661]: Test accuracy=99.2
# Epoch 91/100: loss = [0.01026919]: Test accuracy=99.2
# Epoch 92/100: loss = [0.01021275]: Test accuracy=99.2
# Epoch 93/100: loss = [0.01015727]: Test accuracy=99.2
# Epoch 94/100: loss = [0.01010273]: Test accuracy=99.2
# Epoch 95/100: loss = [0.0100491]: Test accuracy=99.2
# Epoch 96/100: loss = [0.00999636]: Test accuracy=99.2
# Epoch 97/100: loss = [0.00994448]: Test accuracy=99.2
# Epoch 98/100: loss = [0.00989344]: Test accuracy=99.2
# Epoch 99/100: loss = [0.00984323]: Test accuracy=99.2

# %%
#Plot of historic logs
plt.plot(log_train, color='b')
plt.plot(log_test, color='r')

plt.show()

# %%
#Plot the boundary decision

x1_val = np.linspace(X_train[:,0].min(), X_train[:,0].max(), 100)
x2_val = (-b - (w1 * x1_val))/w2


plt.scatter(X_train[:750, 0], X_train[:750, 1], color='b')
plt.scatter(X_train[750:, 0], X_train[750:, 1], color='r')
plt.plot(x1_val, x2_val, 'g')
